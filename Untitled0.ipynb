# %% [markdown]
# <a href="https://colab.research.google.com/github/doniyorbekjaloliddinov/Suniy-intelekt-1dars/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def kasallik(belgi):
  if belgi=="Isitma":
    return "Paratsetamol iching"
  elif belgi=="Bosh ogʻrigʻi":
    return "bolnol iching"
  else:
    return "shifokorga murojat qiling"
belgi=input("kasallik belgisini kiriting: ")
natija=kasallik(belgi)
print(natija)
# Out:
# kasallik belgisini kiriting: Isitma
# Paratsetamol iching
